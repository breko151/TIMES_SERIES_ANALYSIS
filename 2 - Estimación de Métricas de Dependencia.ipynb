# %%
# Execute if necessary
# %%capture
# !pip install numpy seaborn matplotlib pandas

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from typing import Dict, Tuple, Union, List

# %% [markdown]
# # Práctica 2: Estimación de Métricas de Dependencia

# %% [markdown]
# __Instrucciones__: A continuación hay una lista de funciones que debe implementar o tareas que debe desarrollar. La descripción de cada una de ellas se encuentra en la definición de cada una de las funciones. Cada función está marcada por &#x1F625;,  &#x1F643; o &#x1F921;. Las marcas indican:
#
# - &#x1F625;: Indican una entrega que debe ser hecha dentro de la misma sesión de la asignación.
# - &#x1F643;: Indican una entrega que puede ser hecha hasta la siguiente sesión.
# - &#x1F921;: Debe mostrar un avance en la misma sesión, pero la entrega puede ser hecha en la siguiente.
#
# Aquellas entregas parciales que no sean hechas el día de la asignación ya no serán válidas para las entregas totales, sin embargo, las entregas totales seguirán siendo válidas.

# %% [markdown]
# En esta sección se incluye una serie de tiempo real. El dataset importado incluye cuatro series de tiempo de la ciudad de Delhi, India, desde el 1 de enero de 2013 al 1 de enero de 2017 en muestreos diarios. Las series de tiempo incluidas son:
#
# - __meantemp__: Temperatura promedio del día.
# - __humidity__: Humedad promedio del día.
# - __wind_speed__: Velocidad promedio del viento en el día.
# - __meanpressure__: Presión promedio del día.
#
# Este conjunto de datos no contiene datos nulos, por lo que no es necesario realizar una imputación dedatos.

# %%
df = pd.read_csv("DailyDelhiClimateTrain.csv")
df["date"] = pd.to_datetime(df["date"])
df.head(3)
# Out:
#         date   meantemp  humidity  wind_speed  meanpressure
# 0 2013-01-01  10.000000      84.5    0.000000   1015.666667
# 1 2013-01-02   7.400000      92.0    2.980000   1017.800000
# 2 2013-01-03   7.166667      87.0    4.633333   1018.666667

# %% [markdown]
# ## Asignación 1 &#x1F625;
#
# Grafique las series de tiempo __meantemp__, __humidty__ y __wind_speed__.

# %%
# Graficación meantemp
plt.plot(df["date"], df["meantemp"])
plt.title("date vs meantemp")
plt.xlabel("date")
plt.ylabel("meantemp")
plt.show()

# %%
# Graficación humidity
plt.plot(df["date"], df["humidity"])
plt.title("date vs humidity")
plt.xlabel("date")
plt.ylabel("humidity")
plt.show()

# %%
# Graficación wind_speed
plt.plot(df["date"], df["wind_speed"])
plt.title("date vs wind_speed")
plt.xlabel("date")
plt.ylabel("wind_speed")
plt.show()

# %% [markdown]
# ## Asignación 2 &#x1F625;
#
# Grafique el histograma, calcule la media, imprimala y grafíquela en el histograma para las series de tiempo __meantemp__, __humidty__ y __wind_speed__.

# %%
# Obtención de Medias
mean_meantemp = df["meantemp"].mean()
mean_humidity = df["humidity"].mean()
mean_wind_speed = df["wind_speed"].mean()

# %%
# Histograma meantemp
print('Average meantemp:', mean_meantemp)
plt.hist(df["meantemp"])
plt.axvline(mean_meantemp, color='k', linestyle='dashed', linewidth=1)
plt.title("date vs meantemp")
plt.xlabel("date")
plt.ylabel("meantemp")
plt.show()
# Out:
# Average meantemp: 25.495520655761762

# %%
# Histograma humidity
print('Average humidity:', mean_humidity)
plt.hist(df["humidity"])
plt.axvline(mean_humidity, color='k', linestyle='dashed', linewidth=1)
plt.title("date vs humidity")
plt.xlabel("date")
plt.ylabel("humidity")
plt.show()
# Out:
# Average humidity: 60.77170158004638

# %%
# Histograma wind_speed
print('Average wind_speed:', mean_wind_speed)
plt.hist(df["wind_speed"])
plt.axvline(mean_wind_speed, color='k', linestyle='dashed', linewidth=1)
plt.title("date vs wind_speed")
plt.xlabel("date")
plt.ylabel("wind_speed")
plt.show()
# Out:
# Average wind_speed: 6.8022087474474695

# %% [markdown]
# ## Asignación 3 &#x1F625;
#
# Implemente las función de crossvariance descrita debajo

# %%
def crossvariance(
    time_series_1: pd.Series,
    time_series_2: pd.Series,
    lags: Union[List[int], int]
) -> Union[List[float], float]:
    """
    Descripción:
    Esta funcion es la generalización de la autocovarianza.
    
    Entradas:
    - time_series_1: Primera serie de tiempo a utilizar para el cálculo.
    - time_series_2: Segunda serie de tiempo a utilizar para el cálculo.
    - lags: Puede ser uno o varios lags para los cuales debe calcularse la covarianza.
            
    Salidas:
    - Si lags es un número debe regresar un valor de covarianza, si es una lista, 
        debe ser una lista de covarianzas.
    """
    
    # CÓDIGO AQUI
    # Convertimos a arrays de np
    array_1 = np.array(time_series_1)
    array_2 = np.array(time_series_2)
    # Obtenemos medias
    mean_array_1 = time_series_1.mean()
    mean_array_2 = time_series_2.mean()
    # Validamos si lags es un int o una lista
    if type(lags) == int:
        # Generamos nuestros arreglos con lags
        array_2_lags = array_2[lags:]
        array_1_lags = array_1[:len(array_1) - lags]
        # Les restamos las medias
        array_1_lags_mean = array_1_lags - mean_array_1
        array_2_lags_mean = array_2_lags - mean_array_2
        # Hacmos operaciones entre vectores
        crossvariance_result = (1 / len(array_2_lags_mean)) * sum(array_1_lags_mean * array_2_lags_mean)
    else:
        crossvariance_result = list()
        for lag in lags:
            i_result = 0
            array_2_lags = array_2[lag:]
            array_1_lags = array_1[:len(array_1) - lag]
            array_1_lags_mean = array_1_lags - mean_array_1
            array_2_lags_mean = array_2_lags - mean_array_2
            i_result = (1 / len(array_1_lags_mean)) * sum(array_1_lags_mean * array_2_lags_mean)
            crossvariance_result.append(i_result)
    return crossvariance_result

# %%
for __ts__ in ["meantemp", "humidity", "wind_speed"]:
    __cvars__ = crossvariance(df[__ts__], df[__ts__], 0)
    
    if __cvars__ is not None:
        assert np.isclose(__cvars__, df[__ts__].var(ddof=0)), "Your function has an error"

__cvars__ = crossvariance(df["humidity"], df["wind_speed"], np.arange(5).tolist())
__expected_cvars__ = [-28.58795012, -24.37189775, -21.10904889, -19.62116432, -17.42504231] 

if __cvars__ is not None:
    assert np.allclose(__cvars__, __expected_cvars__), "Your function has an error"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [12], in <cell line: 10>()
#       8 __expected_cvars__ = [-28.58795012, -24.37189775, -21.10904889, -19.62116432, -17.42504231]
#      10 if __cvars__ is not None:
# ---> 11     assert np.allclose(__cvars__, __expected_cvars__), "Your function has an error"
#
# AssertionError: Your function has an error

# %%
__cvars__
# Out:
# [-28.587950119792506,
#  -23.757735369328064,
#  -18.41787029305782,
#  -16.067958551593804,
#  -14.898655279457007]

# %% [markdown]
# ## Asignación 4 &#x1F921;
#
# Implemente las función de crosscorrelation.

# %%
def crosscorrelation(

):
    """
    Descripción:
    Esta funcion es la generalización de la correlación. Usted debe definirla y documentarla como en
    el caso de la función crosscovariance.
    
    Entradas:
            
    Salidas:
    """
    
    # CÓDIGO AQUI
    
    return None

# %% [markdown]
# ## Asignación 5 &#x1F643;
#
# Grafique el correlograma de la autocorrelación de la serie de tiempo __wind_speed__ junto con las lineas representativas de 2, 2.5 y 3 veces la desviación estándar (valores de correlaciones de interés).

# %% [markdown]
# ## Asignación 6 &#x1F643;
#
# Grafique el correlograma de la correlación cruzada de la serie de tiempo __wind_speed__ y __humidity__ junto con las lineas representativas de 2, 2.5 y 3 veces la desviación estándar (valores de correlación de interés).

# %% [markdown]
# ## Integrity Tests

# %%
import hashlib

cell_signs = [
    "b133c1b74dff90eff20627c4b853c23441652b2d"
]

for content in _ih:
    content_sign = str(hashlib.sha1(content.strip().encode("utf-8")).hexdigest())
    if content_sign == cell_signs[0]:
        cell_signs.pop(0)
        if len(cell_signs) == 0:
            break
        
if len(cell_signs) > 0:
    print("Something was modified...")
    for cell_sign in cell_signs:
        print(cell_sign)

# %%
content = _ih[-2]

program_sign = "f8ca458c26e5eddbdfe6e06004c808b25a7634ca"
if str(hashlib.sha1(content.strip().encode("utf-8")).hexdigest()) == program_sign:
    print("Everything is consistent :)")
